# %% [markdown]
# <a href="https://colab.research.google.com/github/WEIRUUU/lwr/blob/master/bubblesort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bubble sort (氣泡排序)

# %%
def Bubble_Sort(datas):
    for i in range(1, len(datas)): #獲取資料數量決定執行迴圈次數 
        for j in range(len(datas)-i):   #執行比較迴圈次數，執行次數依當前資料筆數減少，不再與排序完成數量比較 
            if datas[j] > datas[j+1]:   #開始執行比較，判斷當前數值是否大於下一個數值 
                datas[j], datas[j+1] = datas[j+1], datas[j]
    return datas


if __name__ == '__main__':
    import random
    a = [input(),input(),input(),input(),input(),input()]
    random.shuffle(a)
    print(a)
    a = Bubble_Sort(a)
    print(a)

# %% [markdown]
# 請加入註解，並將程式修改為加入六個數做氣泡排序
